# %%
pip install gspread oauth2client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# %%
credentials = ServiceAccountCredentials.from_json_keyfile_name('myprojexttest-356514-99f5278c6d45.json', scope)

# %%
gs = gspread.authorize(credentials)

# %%
SPREADSHEET_KEY = '1wgQVOpSfC62qipwVh2m76MMERSHqv4OhlugpH5ikIyk'

# %%
worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet("スクレイピング")

# %%
# !pip install selenium

# %%
pip install chromedriver
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install fake-useragent

# %%
# !pip install webdriver_manager

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
#from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from time import sleep
from fake_useragent import UserAgent
import time
import numpy as np
import requests
from selenium.webdriver.common.action_chains import ActionChains

# %%
url= "https://httpbin.org/headers"

# %%
r=requests.get(url)

# %%
print(r.text)
# Out:
# {
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-62e1f0a4-767a3a3711a4cdff779a9c92"
#   }
# }

# %%
#user agent偽装を組み込む

ua = UserAgent()

# %%
headers = { "User-Agent":ua.chrome}
r = requests.get(url, headers = headers)
print(r.text)
# Out:
# {
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "Mozilla/5.0 (Windows NT 4.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2049.0 Safari/537.36",
#     "X-Amzn-Trace-Id": "Root=1-62e1f0be-1a4b87407aad35a10ae90a95"
#   }
# }

# %%
url = "https://httpbin.org/headers"

# %%
r=requests.get(url, headers = headers)

# %%
print(r.text)
# Out:
# {
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "Mozilla/5.0 (Windows NT 4.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2049.0 Safari/537.36",
#     "X-Amzn-Trace-Id": "Root=1-62e1f0ce-3312c8c625d7365a3b634405"
#   }
# }

# %%
#ランダムな待機時間を設定（これはメソッド化して、各操作前に呼び出したい感じ）

def wait_t():
    wait_time = float('{:.3f}'.format(np.random.rand()*2+5))
    return wait_time

# %%
#ブラウザの立ち上げ

driver = webdriver.Chrome (ChromeDriverManager().install())

# %%
#Linkedinサイトへアクセス
#Linkedinトップページ


driver.get('https://www.linkedin.com/login/ja?fromSignIn=true&trk=guest_homepage-basic_nav-header-signin')

# %%
#自動ログイン
#ユーザー名入力

mail = driver.find_element_by_id("username")
mail.send_keys("yasuaki.hikasa@divx.co.jp")

#間隔空ける

time.sleep(wait_t())

#パスワード入力

password = driver.find_element_by_id("password")
password.send_keys("yasu0118")
btn = driver.find_element_by_xpath('//*[@id="organic-div"]/form/div[3]/button')

time.sleep(wait_t())
print(wait_t())

#サインインボタン押す

btn.click()

print(link.text)

# %%
#検索
search_user = driver.find_element_by_class_name("search-global-typeahead__input")
search_user.send_keys("CEO")
input_element = driver.find_element_by_class_name('search-global-typeahead__input')
input_element.send_keys(Keys.ENTER)

# %%
#フィルター検索
filter_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/section/div/nav/div/ul/li[1]/button')
filter_element.send_keys(Keys.ENTER)

# %%
#書き込むスプレッドシートの行を初期化
i=2

# %%
for search in range(3):

    #１番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[1]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[1]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン2失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[1]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン3失敗")    
    time.sleep(wait_t()) 

    #名前を取得
    try:
        name_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[1]/h1").text
        print(name_element)
        time.sleep(wait_t()) 

    #連絡先情報ページへ遷移
        link_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[2]/span[2]/a')
        link_element.click()

        time.sleep(wait_t()) 

    #連絡先情報URLの取得
        url_element = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/section/div/section/div/a").text
        print(url_element)

        time.sleep(wait_t()) 

    #スプレッドシートへの書き出し

        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('スクレイピング')
        name_cell = "B"+str(i)
        url_cell = "C"+str(i)
        worksheet.update_acell(name_cell, name_element)
        time.sleep(wait_t()) 
        worksheet.update_acell(url_cell, url_element)
        i+=1

    #ブラウザバック２回
        driver.back()
        time.sleep(wait_t()) 
        driver.back()

        time.sleep(wait_t()) 

    except Exception: 
        print("1番目失敗") 

    #2番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[2]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[2]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン2失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[2]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン3失敗")    
    time.sleep(wait_t()) 

    #名前を取得
    try:
        name_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[1]/h1").text
        print(name_element)
        time.sleep(wait_t()) 

    #連絡先情報ページへ遷移
        link_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[2]/span[2]/a')
        link_element.click()

        time.sleep(wait_t()) 

    #連絡先情報URLの取得
        url_element = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/section/div/section/div/a").text
        print(url_element)

        time.sleep(wait_t()) 

    #スプレッドシートへの書き出し

        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('スクレイピング')
        name_cell = "B"+str(i)
        url_cell = "C"+str(i)
        worksheet.update_acell(name_cell, name_element)
        time.sleep(wait_t()) 
        worksheet.update_acell(url_cell, url_element)
        i+=1

    #ブラウザバック２回
        driver.back()
        time.sleep(wait_t()) 
        driver.back()

        time.sleep(wait_t()) 

    except Exception: 
        print("2番目失敗") 

    #3番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[3]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[3]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン2失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[3]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン3失敗")    
    time.sleep(wait_t()) 

    #名前を取得
    try:
        name_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[1]/h1").text
        print(name_element)
        time.sleep(wait_t()) 

    #連絡先情報ページへ遷移
        link_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[2]/span[2]/a')
        link_element.click()

        time.sleep(wait_t()) 

    #連絡先情報URLの取得
        url_element = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/section/div/section/div/a").text
        print(url_element)

        time.sleep(wait_t()) 

    #スプレッドシートへの書き出し

        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('スクレイピング')
        name_cell = "B"+str(i)
        url_cell = "C"+str(i)
        worksheet.update_acell(name_cell, name_element)
        time.sleep(wait_t()) 
        worksheet.update_acell(url_cell, url_element)
        i+=1

    #ブラウザバック２回
        driver.back()
        time.sleep(wait_t()) 
        driver.back()

        time.sleep(wait_t()) 

    except Exception: 
        print("3番目失敗")  


    #4番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[4]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[4]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン2失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[4]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン3失敗")    
    time.sleep(wait_t()) 

    #名前を取得
    try:
        name_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[1]/h1").text
        print(name_element)
        time.sleep(wait_t()) 

    #連絡先情報ページへ遷移
        link_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[2]/span[2]/a')
        link_element.click()

        time.sleep(wait_t()) 

    #連絡先情報URLの取得
        url_element = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/section/div/section/div/a").text
        print(url_element)

        time.sleep(wait_t()) 

    #スプレッドシートへの書き出し

        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('スクレイピング')
        name_cell = "B"+str(i)
        url_cell = "C"+str(i)
        worksheet.update_acell(name_cell, name_element)
        time.sleep(wait_t()) 
        worksheet.update_acell(url_cell, url_element)
        i+=1

    #ブラウザバック２回
        driver.back()
        time.sleep(wait_t()) 
        driver.back()

        time.sleep(wait_t()) 

    except Exception: 
        print("4番目失敗") 


    #5番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[5]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[5]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン2失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[5]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン3失敗")    
    time.sleep(wait_t()) 

    #名前を取得
    try:
        name_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[1]/h1").text
        print(name_element)
        time.sleep(wait_t()) 

    #連絡先情報ページへ遷移
        link_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[2]/span[2]/a')
        link_element.click()

        time.sleep(wait_t()) 

    #連絡先情報URLの取得
        url_element = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/section/div/section/div/a").text
        print(url_element)

        time.sleep(wait_t()) 

    #スプレッドシートへの書き出し

        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('スクレイピング')
        name_cell = "B"+str(i)
        url_cell = "C"+str(i)
        worksheet.update_acell(name_cell, name_element)
        time.sleep(wait_t()) 
        worksheet.update_acell(url_cell, url_element)
        i+=1

    #ブラウザバック２回
        driver.back()
        time.sleep(wait_t()) 
        driver.back()

        time.sleep(wait_t()) 

    except Exception: 
        print("5番目失敗") 

    #6番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[6]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[6]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン2失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[6]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン3失敗")    
    time.sleep(wait_t()) 

    #名前を取得
    try:
        name_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[1]/h1").text
        print(name_element)
        time.sleep(wait_t()) 

    #連絡先情報ページへ遷移
        link_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[2]/span[2]/a')
        link_element.click()

        time.sleep(wait_t()) 

    #連絡先情報URLの取得
        url_element = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/section/div/section/div/a").text
        print(url_element)

        time.sleep(wait_t()) 

    #スプレッドシートへの書き出し

        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('スクレイピング')
        name_cell = "B"+str(i)
        url_cell = "C"+str(i)
        worksheet.update_acell(name_cell, name_element)
        time.sleep(wait_t()) 
        worksheet.update_acell(url_cell, url_element)
        i+=1

    #ブラウザバック２回
        driver.back()
        time.sleep(wait_t()) 
        driver.back()

        time.sleep(wait_t()) 

    except Exception: 
        print("6番目失敗") 

    #7番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[7]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[7]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン2失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[7]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン3失敗")    
    time.sleep(wait_t()) 

    #名前を取得
    try:
        name_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[1]/h1").text
        print(name_element)
        time.sleep(wait_t()) 

    #連絡先情報ページへ遷移
        link_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[2]/span[2]/a')
        link_element.click()

        time.sleep(wait_t()) 

    #連絡先情報URLの取得
        url_element = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/section/div/section/div/a").text
        print(url_element)

        time.sleep(wait_t()) 

    #スプレッドシートへの書き出し

        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('スクレイピング')
        name_cell = "B"+str(i)
        url_cell = "C"+str(i)
        worksheet.update_acell(name_cell, name_element)
        time.sleep(wait_t()) 
        worksheet.update_acell(url_cell, url_element)
        i+=1

    #ブラウザバック２回
        driver.back()
        time.sleep(wait_t()) 
        driver.back()

        time.sleep(wait_t()) 

    except Exception: 
        print("7番目失敗") 


    #8番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[8]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[8]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン2失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[8]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン3失敗")    
    time.sleep(wait_t()) 

    #名前を取得
    try:
        name_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[1]/h1").text
        print(name_element)
        time.sleep(wait_t()) 

    #連絡先情報ページへ遷移
        link_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[2]/span[2]/a')
        link_element.click()

        time.sleep(wait_t()) 

    #連絡先情報URLの取得
        url_element = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/section/div/section/div/a").text
        print(url_element)

        time.sleep(wait_t()) 

    #スプレッドシートへの書き出し

        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('スクレイピング')
        name_cell = "B"+str(i)
        url_cell = "C"+str(i)
        worksheet.update_acell(name_cell, name_element)
        time.sleep(wait_t()) 
        worksheet.update_acell(url_cell, url_element)
        i+=1

    #ブラウザバック２回
        driver.back()
        time.sleep(wait_t()) 
        driver.back()

        time.sleep(wait_t()) 

    except Exception: 
        print("8番目失敗") 

    #9番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[9]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[9]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン2失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[9]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン3失敗")    
    time.sleep(wait_t()) 

    #名前を取得
    try:
        name_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[1]/h1").text
        print(name_element)
        time.sleep(wait_t()) 

    #連絡先情報ページへ遷移
        link_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[2]/span[2]/a')
        link_element.click()

        time.sleep(wait_t()) 

    #連絡先情報URLの取得
        url_element = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/section/div/section/div/a").text
        print(url_element)

        time.sleep(wait_t()) 

    #スプレッドシートへの書き出し

        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('スクレイピング')
        name_cell = "B"+str(i)
        url_cell = "C"+str(i)
        worksheet.update_acell(name_cell, name_element)
        time.sleep(wait_t()) 
        worksheet.update_acell(url_cell, url_element)
        i+=1

    #ブラウザバック２回
        driver.back()
        time.sleep(wait_t()) 
        driver.back()

        time.sleep(wait_t()) 

    except Exception: 
        print("9番目失敗") 


    #１0番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[10]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[10]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン2失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[10]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
    except Exception: 
        print("パターン3失敗")    
    time.sleep(wait_t()) 

    #名前を取得
    try:
        name_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[1]/h1").text
        print(name_element)
        time.sleep(wait_t()) 

    #連絡先情報ページへ遷移
        link_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[2]/span[2]/a')
        link_element.click()

        time.sleep(wait_t()) 

    #連絡先情報URLの取得
        url_element = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/section/div/section/div/a").text
        print(url_element)

        time.sleep(wait_t()) 

    #スプレッドシートへの書き出し

        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('スクレイピング')
        name_cell = "B"+str(i)
        url_cell = "C"+str(i)
        worksheet.update_acell(name_cell, name_element)
        time.sleep(wait_t()) 
        worksheet.update_acell(url_cell, url_element)
        i+=1

    #ブラウザバック２回
        driver.back()
        time.sleep(wait_t()) 
        driver.back()

        time.sleep(wait_t())
        time.sleep(wait_t())

    except Exception: 
        print("10番目失敗") 
        time.sleep(wait_t())
        time.sleep(wait_t())


    #ページネーションまでスクロールして次のページへ遷移
    try:
        element1 = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[9]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]")
        actions = ActionChains(driver)
        actions.move_to_element(element1)
        actions.perform()
        time.sleep(wait_t())
    except Exception: 
        print("要素なし1")    

    try:
        element2 = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[10]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]")
        actions = ActionChains(driver)
        actions.move_to_element(element2)
        actions.perform()
        time.sleep(wait_t())
    except Exception: 
        print("要素なし2")     

    try:
        element3 = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/div[2]/div/button[2]")
        actions = ActionChains(driver)
        actions.move_to_element(element3)
        actions.perform()
        time.sleep(wait_t())
    except Exception: 
        print("要素なし3")     


    try:
        element4 = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[5]/div/div/button[2]")
        actions = ActionChains(driver)
        actions.move_to_element(element4)
        actions.perform()
    except Exception: 
        print("ページネーションへスクロール失敗1-1")

    try:
        element5 = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/div[2]/div/button[2]")
        actions = ActionChains(driver)
        actions.move_to_element(element5)
        actions.perform()
    except Exception: 
        print("ページネーションへスクロール失敗1-2")

    time.sleep(wait_t()) 
    try:
        pageNation_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[5]/div/div/button[2]')
        pageNation_element.click()
    except Exception: 
        print("ページネーションクリック失敗1")

    try:
        pageNation_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/div[2]/div/button[2]')
        pageNation_element.click()
    except Exception: 
        print("ページネーションクリック失敗2")
        
    finally:
        time.sleep(wait_t())
