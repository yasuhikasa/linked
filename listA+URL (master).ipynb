# %%
#書き込みを始めるスプレッドシートの行を設定
i=2

# %%
#スクレイピングを始めるURLを指定
#↓テスト用
#start_url="https://www.linkedin.com/search/results/people/?geoUrn=%5B%22101355337%22%5D&industry=%5B%2296%22%2C%224%22%5D&origin=GLOBAL_SEARCH_HEADER&page=21&title=%E5%8F%96%E7%B7%A0%E5%BD%B9"

start_url="https://www.linkedin.com/search/results/people/?geoUrn=%5B%22101355337%22%5D&network=%5B%22O%22%5D&origin=FACETED_SEARCH&serviceCategory=%5B%22764%22%2C%221383%22%2C%2255798%22%2C%2250304%22%2C%223166%22%2C%2255797%22%2C%223498%22%2C%225171%22%2C%2226904%22%5D&sid=7ug&title=%E4%BB%A3%E8%A1%A8%E5%8F%96%E7%B7%A0%E5%BD%B9"

# %%
#スクレイピングを行うページ数を入力
get_page=1

# %%
#linkedinユーザーアカウント
u_name="yasuhikasa@yahoo.co.jp"

#linkedinパスワード
u_password="yasu0118"

# %%
pip install gspread oauth2client
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#スプレッドシートを扱うライブラリ（gspread）のインストール

import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# %%
#jsonファイルを設置
credentials = ServiceAccountCredentials.from_json_keyfile_name('saitou.json', scope)

# ↓日笠用
# credentials = ServiceAccountCredentials.from_json_keyfile_name('myprojexttest-356514-99f5278c6d45.json', scope)

# %%
gs = gspread.authorize(credentials)

# %%
#扱うスプレッドシートのURL情報を入力
#SPREADSHEET_KEY = '1R7Q0TjK3PWdlI0e0plXa7jRgOhMyTJv5sMU7Ut_FvT4'

#日笠テスト用
SPREADSHEET_KEY = '1wgQVOpSfC62qipwVh2m76MMERSHqv4OhlugpH5ikIyk'

# %%
#スプレッドシートのシート名を入力
worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet("Aタイプ+URL")

# %%
# !pip install selenium
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
pip install chromedriver
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install fake-useragent
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install webdriver_manager
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
#from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from time import sleep
from fake_useragent import UserAgent
import time
import numpy as np
import requests
from selenium.webdriver.common.action_chains import ActionChains

# %%
url= "https://httpbin.org/headers"

# %%
r=requests.get(url)

# %%
print(r.text)
# Out:
# {
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-62f50812-71d0bca82ea7dd37619c759a"
#   }
# }

# %%
#user agent偽装を組み込む

ua = UserAgent()

# %%
headers = { "User-Agent":ua.chrome}
r = requests.get(url, headers = headers)
print(r.text)
# Out:
# {
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.16 Safari/537.36",
#     "X-Amzn-Trace-Id": "Root=1-62f50813-63885b35637f46ab2bb034e4"
#   }
# }

# %%
url = "https://httpbin.org/headers"

# %%
r=requests.get(url, headers = headers)

# %%
print(r.text)
# Out:
# {
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.16 Safari/537.36",
#     "X-Amzn-Trace-Id": "Root=1-62f50814-284e045771fb6ab34e7faf6f"
#   }
# }

# %%
#ランダムな待機時間を設定（これはメソッド化して、各操作前に呼び出したい感じ）

def wait_t():
    wait_time = float('{:.3f}'.format(np.random.rand()*2+3))
    return wait_time

# %%
from webdriver_manager.chrome import ChromeDriverManager
import chromedriver_autoinstaller as chromedriver
chromedriver.install()
# Out:
# '/Users/divx/opt/anaconda3/lib/python3.9/site-packages/chromedriver_autoinstaller/104/chromedriver'

# %%
#ブラウザの立ち上げ

driver = webdriver.Chrome ()

# %%
#Linkedinサイトへアクセス
#Linkedinトップページ


driver.get('https://www.linkedin.com/login/ja?fromSignIn=true&trk=guest_homepage-basic_nav-header-signin')

# %%
#自動ログイン
#ユーザー名入力

mail = driver.find_element_by_id("username")
mail.send_keys(u_name)

#間隔空ける

time.sleep(wait_t())

#パスワード入力

password = driver.find_element_by_id("password")
password.send_keys(u_password)

btn = driver.find_element_by_xpath('//*[@id="organic-div"]/form/div[3]/button')

time.sleep(wait_t())
print(wait_t())

#サインインボタン押す

btn.click()
# Out:
# /var/folders/z0/3dq3ynpj06sdcjdcl_dqb3lh0000gn/T/ipykernel_49093/2774415192.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   mail = driver.find_element_by_id("username")
# /var/folders/z0/3dq3ynpj06sdcjdcl_dqb3lh0000gn/T/ipykernel_49093/2774415192.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   password = driver.find_element_by_id("password")
# /var/folders/z0/3dq3ynpj06sdcjdcl_dqb3lh0000gn/T/ipykernel_49093/2774415192.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   btn = driver.find_element_by_xpath('//*[@id="organic-div"]/form/div[3]/button')
# 4.908

# %%
#冒頭で入力したURLへ遷移

driver.get(start_url)

# %%
#実際に１列目のプロフィールから順にスクレイピングを行っていくプログラム
for search in range(get_page): 
    
    #1番目の処理開始
    #linkedinユーザーの表記の人をスキップした上で、ブラウザバックをコントロールにするbooleanを初期化
    #プロフィールページに遷移できたらtrue、遷移できなければfalse
    can_access = False
    
    friend = ""
    #１番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[1]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[1]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン2失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[1]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン3失敗") 
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[1]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン4失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[1]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン5失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[1]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン6失敗")
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[1]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン7失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[1]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン8失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[1]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン9失敗") 
    time.sleep(wait_t()) 
       
    #山根大毅と共通の知人かチェック
    try:
        friend = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-1")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-2")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-3")

    #ブラウザバックをコントロールするbooleanを初期化
    #スプレッドシートに記入できればtrue,できなければfalse
    success = False
    
    #情報取得
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("1-1番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("1-2番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("1-3番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("1-4番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)                          
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("1-5番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("1-6番目失敗")
        
    #プロフィールページに遷移できたが、スプレッドシートに記入できなかったら、一つブラウザバックして次のプロフィールページへ処理を移る
    #linkedinユーザー表記の場合は次の行のスクレイピングへ移る
    if success == False and can_access == True:
        time.sleep(wait_t())
        driver.back()
        
    #2番目の処理開始
    #linkedinユーザーの表記の人をスキップした上で、ブラウザバックをコントロールにするbooleanを初期化
    #プロフィールページに遷移できたらtrue、遷移できなければfalse
    can_access = False
    
    friend = ""
    #2番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[2]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[2]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン2失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[2]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン3失敗") 
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[2]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン4失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[2]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン5失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[2]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン6失敗")
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[2]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン7失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[2]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン8失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[2]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン9失敗") 
    time.sleep(wait_t()) 
       
    #山根大毅と共通の知人かチェック
    try:
        friend = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-1")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-2")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-3")

    #ブラウザバックをコントロールするbooleanを初期化
    #スプレッドシートに記入できればtrue,できなければfalse
    success = False
    
    #情報取得
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("2-1番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("2-2番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("2-3番目失敗") 

        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("2-4番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)                          
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("2-5番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("2-6番目失敗")
        
    #プロフィールページに遷移できたが、スプレッドシートに記入できなかったら、一つブラウザバックして次のプロフィールページへ処理を移る
    #linkedinユーザー表記の場合は次の行のスクレイピングへ移る
    if success == False and can_access == True:
        time.sleep(wait_t())
        driver.back()

        
    #3番目の処理開始
    #linkedinユーザーの表記の人をスキップした上で、ブラウザバックをコントロールにするbooleanを初期化
    #プロフィールページに遷移できたらtrue、遷移できなければfalse
    can_access = False
    
    friend = ""
    #3番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[3]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[3]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン2失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[3]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン3失敗") 
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[3]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン4失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[3]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン5失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[3]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン6失敗")
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[3]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン7失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[3]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン8失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[3]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン9失敗") 
    time.sleep(wait_t()) 
       
    #山根大毅と共通の知人かチェック
    try:
        friend = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-1")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-2")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-3")

    #ブラウザバックをコントロールするbooleanを初期化
    #スプレッドシートに記入できればtrue,できなければfalse
    success = False
    
    #情報取得
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("3-1番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("3-2番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("3-3番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("3-4番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)                          
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("3-5番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("3-6番目失敗")
        
    #プロフィールページに遷移できたが、スプレッドシートに記入できなかったら、一つブラウザバックして次のプロフィールページへ処理を移る
    #linkedinユーザー表記の場合は次の行のスクレイピングへ移る
    if success == False and can_access == True:
        time.sleep(wait_t())
        driver.back()

    #4番目の処理開始
    #linkedinユーザーの表記の人をスキップした上で、ブラウザバックをコントロールにするbooleanを初期化
    #プロフィールページに遷移できたらtrue、遷移できなければfalse
    can_access = False
    
    friend = ""
    #4番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[4]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[4]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン2失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[4]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン3失敗") 
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[4]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン4失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[4]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン5失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[4]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン6失敗")
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[4]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン7失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[4]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン8失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[4]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン9失敗") 
    time.sleep(wait_t()) 
       
    #山根大毅と共通の知人かチェック
    try:
        friend = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-1")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-2")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-3")

    #ブラウザバックをコントロールするbooleanを初期化
    #スプレッドシートに記入できればtrue,できなければfalse
    success = False
    
    #情報取得
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t())

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("4-1番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("4-2番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("4-3番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("4-4番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)                          
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("4-5番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("4-6番目失敗")
        
    #プロフィールページに遷移できたが、スプレッドシートに記入できなかったら、一つブラウザバックして次のプロフィールページへ処理を移る
    #linkedinユーザー表記の場合は次の行のスクレイピングへ移る
    if success == False and can_access == True:
        time.sleep(wait_t())
        driver.back()  
        
    #5番目の処理開始
    #linkedinユーザーの表記の人をスキップした上で、ブラウザバックをコントロールにするbooleanを初期化
    #プロフィールページに遷移できたらtrue、遷移できなければfalse
    can_access = False
    
    friend = ""
    #5番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[5]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[5]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン2失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[5]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン3失敗") 
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[5]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン4失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[5]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン5失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[5]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン6失敗")
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[5]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン7失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[5]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン8失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[5]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン9失敗") 
    time.sleep(wait_t()) 
       
    #山根大毅と共通の知人かチェック
    try:
        friend = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-1")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-2")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-3")

    #ブラウザバックをコントロールするbooleanを初期化
    #スプレッドシートに記入できればtrue,できなければfalse
    success = False
    
    #情報取得
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t())

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("5-1番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("5-2番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("5-3番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("5-4番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)                          
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("5-5番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("5-6番目失敗")
        
    #プロフィールページに遷移できたが、スプレッドシートに記入できなかったら、一つブラウザバックして次のプロフィールページへ処理を移る
    #linkedinユーザー表記の場合は次の行のスクレイピングへ移る
    if success == False and can_access == True:
        time.sleep(wait_t())
        driver.back()

        
    #6番目の処理開始
    #linkedinユーザーの表記の人をスキップした上で、ブラウザバックをコントロールにするbooleanを初期化
    #プロフィールページに遷移できたらtrue、遷移できなければfalse
    can_access = False
    
    friend = ""
    #6番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[6]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[6]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン2失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[6]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン3失敗") 
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[6]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン4失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[6]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン5失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[6]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン6失敗")
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[6]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン7失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[6]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン8失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[6]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン9失敗") 
    time.sleep(wait_t()) 
       
    #山根大毅と共通の知人かチェック
    try:
        friend = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-1")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-2")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-3")

    #ブラウザバックをコントロールするbooleanを初期化
    #スプレッドシートに記入できればtrue,できなければfalse
    success = False
    
    #情報取得
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t())

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("6-1番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t())
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("6-2番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("6-3番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("6-4番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)                          
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("6-5番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("6-6番目失敗")
        
    #プロフィールページに遷移できたが、スプレッドシートに記入できなかったら、一つブラウザバックして次のプロフィールページへ処理を移る
    #linkedinユーザー表記の場合は次の行のスクレイピングへ移る
    if success == False and can_access == True:
        time.sleep(wait_t())
        driver.back()      

    #7番目の処理開始
    #linkedinユーザーの表記の人をスキップした上で、ブラウザバックをコントロールにするbooleanを初期化
    #プロフィールページに遷移できたらtrue、遷移できなければfalse
    can_access = False
    
    friend = ""
    #7番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[7]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[7]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン2失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[7]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン3失敗") 
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[7]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン4失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[7]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン5失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[7]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン6失敗")
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[7]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン7失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[7]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン8失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[7]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン9失敗") 
    time.sleep(wait_t()) 
       
    #山根大毅と共通の知人かチェック
    try:
        friend = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-1")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-2")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-3")

    #ブラウザバックをコントロールするbooleanを初期化
    #スプレッドシートに記入できればtrue,できなければfalse
    success = False
    
    #情報取得
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("7-1番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")  
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("7-2番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("7-3番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("7-4番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)                          
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("7-5番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("7-6番目失敗")
        
    #プロフィールページに遷移できたが、スプレッドシートに記入できなかったら、一つブラウザバックして次のプロフィールページへ処理を移る
    #linkedinユーザー表記の場合は次の行のスクレイピングへ移る
    if success == False and can_access == True:
        time.sleep(wait_t())
        driver.back()        
        
    #8番目の処理開始
    #linkedinユーザーの表記の人をスキップした上で、ブラウザバックをコントロールにするbooleanを初期化
    #プロフィールページに遷移できたらtrue、遷移できなければfalse
    can_access = False
    
    friend = ""
    #8番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[8]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[8]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン2失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[8]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン3失敗") 
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[8]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン4失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[8]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン5失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[8]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン6失敗")
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[8]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン7失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[8]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン8失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[8]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン9失敗") 
    time.sleep(wait_t()) 
       
    #山根大毅と共通の知人かチェック
    try:
        friend = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-1")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-2")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-3")

    #ブラウザバックをコントロールするbooleanを初期化
    #スプレッドシートに記入できればtrue,できなければfalse
    success = False
    
    #情報取得
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("8-1番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t())
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")  
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("8-2番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")  
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("8-3番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("8-4番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)                          
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("8-5番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("8-6番目失敗")
        
    #プロフィールページに遷移できたが、スプレッドシートに記入できなかったら、一つブラウザバックして次のプロフィールページへ処理を移る
    #linkedinユーザー表記の場合は次の行のスクレイピングへ移る
    if success == False and can_access == True:
        time.sleep(wait_t())
        driver.back()        

    #9番目の処理開始
    #linkedinユーザーの表記の人をスキップした上で、ブラウザバックをコントロールにするbooleanを初期化
    #プロフィールページに遷移できたらtrue、遷移できなければfalse
    can_access = False
    
    friend = ""
    #9番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[9]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[9]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン2失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[9]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン3失敗") 
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[9]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン4失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[9]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン5失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[9]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン6失敗")
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[9]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン7失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[9]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン8失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[9]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン9失敗") 
    time.sleep(wait_t()) 
       
    #山根大毅と共通の知人かチェック
    try:
        friend = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-1")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-2")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-3")

    #ブラウザバックをコントロールするbooleanを初期化
    #スプレッドシートに記入できればtrue,できなければfalse
    success = False
    
    #情報取得
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")  
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("9-1番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("9-2番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")  
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("9-3番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("9-4番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)                          
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("9-5番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("9-6番目失敗")
        
    #プロフィールページに遷移できたが、スプレッドシートに記入できなかったら、一つブラウザバックして次のプロフィールページへ処理を移る
    #linkedinユーザー表記の場合は次の行のスクレイピングへ移る
    if success == False and can_access == True:
        time.sleep(wait_t())
        driver.back()        

    #10番目の処理開始
    #linkedinユーザーの表記の人をスキップした上で、ブラウザバックをコントロールにするbooleanを初期化
    #プロフィールページに遷移できたらtrue、遷移できなければfalse
    can_access = False
    
    friend = ""
    #１0番目のプロフィールページへ遷移
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[10]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン１失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[10]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン2失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[10]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン3失敗") 
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[10]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン4失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[10]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン5失敗") 
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[10]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン6失敗")
    try:
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[10]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン7失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[10]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン8失敗")
    try:    
        profile_element = driver.find_element_by_xpath('/html/body/div[4]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[10]/div/div/div[2]/div/div[1]/div/span[1]/span/a/span/span[1]')
        profile_element.click()
        can_access = True
    except Exception: 
        print("パターン9失敗") 
    time.sleep(wait_t()) 
       
    #山根大毅と共通の知人かチェック
    try:
        friend = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-1")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-2")
    try:
        friend = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/a/span/span[1]").text             
    except Exception:
        print("共通の知人と判別できず-3")
        
    #ブラウザバックをコントロールするbooleanを初期化
    #スプレッドシートに記入できればtrue,できなければfalse
    success = False
    
    #情報取得
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t())

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")  
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("10-1番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("10-2番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("10-3番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[6]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE")
        success=True
        i+=1

    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("10-4番目失敗")
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[5]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)                          
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 
        
    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1      


    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
        
    except Exception: 
        print("10-5番目失敗") 
        
    #2列目情報の取得
    try:
        prof_element = driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/div/div/div[2]/div/div/main/section[1]/div[2]/div[2]/div[1]/div[2]").text
        print(prof_element)
        time.sleep(wait_t()) 
        
    #名前を取得    
        name_element = driver.find_element_by_class_name("text-heading-xlarge").text
        print(name_element)
        time.sleep(wait_t()) 

    #URL情報の取得
        url_element=driver.current_url
        print(url_element)
        time.sleep(wait_t()) 
    
    #スプレッドシートへの書き出し
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
        name_cell = "B"+str(i)
        url_cell = "D"+str(i)
        prof_cell = "C"+str(i)      
        worksheet.update_acell(name_cell, name_element)
        worksheet.update_acell(url_cell, url_element) 
        worksheet.update_acell(prof_cell, prof_element)
    #山根大毅とつながりがあればA列にTRUE、なければFALSEを記入
        if "山根 大毅" in friend:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "TRUE") 
        else:
            worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('Aタイプ+URL')
            friend_cell = "A"+str(i)
            worksheet.update_acell(friend_cell, "FALSE") 
        success=True
        i+=1
        
        
    #ブラウザバック
        driver.back()
        time.sleep(wait_t()) 
       
    except Exception: 
        print("10-6番目失敗")
        
    #プロフィールページに遷移できたが、スプレッドシートに記入できなかったら、一つブラウザバックして次のプロフィールページへ処理を移る
    #linkedinユーザー表記の場合は次の行のスクレイピングへ移る
    if success == False and can_access == True:
        time.sleep(wait_t())
        driver.back()        
        
    #ページネーションまでスクロールして次のページへ遷移
    #ページ最下部へ移動
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    time.sleep(wait_t()) 


    pageNation_element = driver.find_element_by_xpath('//*[text()="次へ"]')
    pageNation_element.click()
# Out:
# /var/folders/z0/3dq3ynpj06sdcjdcl_dqb3lh0000gn/T/ipykernel_49093/2669847280.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div[2]/ul/li[1]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
# /var/folders/z0/3dq3ynpj06sdcjdcl_dqb3lh0000gn/T/ipykernel_49093/2669847280.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   profile_element = driver.find_element_by_xpath('/html/body/div[6]/div[3]/div[2]/div/div[1]/main/div/div/div/ul/li[1]/div/div/div[2]/div[1]/div[1]/div/span[1]/span/a/span/span[1]')
# /var/folders/z0/3dq3ynpj06sdcjdcl_dqb3lh0000gn/T/ipykernel_49093/2669847280.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...
